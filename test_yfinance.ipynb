# %%
import yfinance as yf

# %% [markdown]
# - docs: https://github.com/ranaroussi/yfinance

# %%
msft = yf.Ticker('MSFT')

# %%
msft.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
#  'longBusinessSummary': "Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company's Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); and Skype, Outlook.com, and OneDrive. It also provides LinkedIn that includes Talent and marketing solutions, and subscriptions; and Dynamics 365, a set of cloud-based and on-premises business solutions for small and medium businesses, large organizations, and divisions of enterprises. The company's Intelligent Cloud segment licenses SQL and Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also provides support services and Microsoft consulting services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification to developers and IT professionals on various Microsoft products. The company's More Personal Computing segment offers Windows OEM licensing and other non-volume licensing of the Windows operating system; Windows Commercial comprising volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; Windows Internet of Things; and MSN advertising. It also provides Microsoft Surface, PC accessories, and other intelligent devices; Gaming, including Xbox hardware, and Xbox software and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through distributors and resellers; and directly through digital marketplaces, online stores, and retail stores. It has strategic partnerships with Humana Inc. and Nokia. The company was founded in 1975 and is headquartered in Redmond, Washington.",
#  'city': 'Redmond',
#  'phone': '425-882-8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'fax': '425-706-7329',
#  'industry': 'Software—Infrastructure',
#  'previousClose': 146.92,
#  'regularMarketOpen': 148.91,
#  'twoHundredDayAverage': 153.50385,
#  'trailingAnnualDividendYield': 0.013204466,
#  'payoutRatio': 0.32930002,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 156.66,
#  'navPrice': None,
#  'averageDailyVolume10Day': 82301475,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 146.92,
#  'fiftyDayAverage': 164.96028,
#  'trailingAnnualDividendRate': 1.94,
#  'open': 148.91,
#  'toCurrency': None,
#  'averageVolume10days': 82301475,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 2.04,
#  'exDividendDate': 1589932800,
#  'beta': 1.091844,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 148.37,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 27.192125,
#  'regularMarketVolume': 62008929,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1187380461568,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 46185129,
#  'priceToSalesTrailing12Months': 8.844613,
#  'dayLow': 148.37,
#  'ask': 156.36,
#  'ytdReturn': None,
#  'askSize': 900,
#  'volume': 62008929,
#  'fiftyTwoWeekHigh': 190.7,
#  'forwardPE': 25.01763,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2,
#  'fiftyTwoWeekLow': 116.13,
#  'bid': 155.25,
#  'tradeable': True,
#  'dividendYield': 0.0139,
#  'bidSize': 1000,
#  'dayHigh': 156.66,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 7.973,
#  'beta3Year': None,
#  'profitMargins': 0.33016,
#  'enterpriseToEbitda': 17.472,
#  '52WeekChange': 0.2564782,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.24,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7606049792,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 14.467,
#  'sharesShort': 55155176,
#  'sharesPercentSharesOut': 0.0073,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1561852800,
#  'heldPercentInstitutions': 0.74406,
#  'netIncomeToCommon': 44323000320,
#  'trailingEps': 5.741,
#  'lastDividendValue': None,
#  'SandP52WeekChange': -0.12071997,
#  'priceToBook': 10.790765,
#  'heldPercentInsiders': 0.01421,
#  'nextFiscalYearEnd': 1625011200,
#  'mostRecentQuarter': 1577750400,
#  'shortRatio': 0.91,
#  'sharesShortPreviousMonthDate': 1581638400,
#  'floatShares': 7495074784,
#  'enterpriseValue': 1070396407808,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.383,
#  'dateShortInterest': 1584057600,
#  'pegRatio': 1.84,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0073,
#  'sharesShortPriorMonth': 56193866,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 148.91,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com'}

# %%
sp500 = yf.Ticker('^GSPC')

# %%
sp500.info
# Out:
# {'previousClose': 2475.56,
#  'regularMarketOpen': 2501.29,
#  'twoHundredDayAverage': 3074.0713,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 2637.01,
#  'navPrice': None,
#  'averageDailyVolume10Day': 8140302500,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 2475.56,
#  'fiftyDayAverage': 2962.6382,
#  'trailingAnnualDividendRate': None,
#  'open': 2501.29,
#  'toCurrency': None,
#  'averageVolume10days': 8140302500,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 2500.72,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 45919738,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 4958584516,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 2500.72,
#  'ask': 2749.3,
#  'ytdReturn': None,
#  'askSize': 0,
#  'volume': 45919738,
#  'fiftyTwoWeekHigh': 3393.52,
#  'forwardPE': None,
#  'maxAge': 1,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 2191.86,
#  'bid': 2570.77,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 0,
#  'dayHigh': 2637.01,
#  'exchange': 'SNP',
#  'shortName': 'S&P 500',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'INDEX',
#  'symbol': '^GSPC',
#  'messageBoardId': 'finmb_INDEXGSPC',
#  'market': 'us_market',
#  'regularMarketPrice': 2501.29,
#  'logo_url': ''}

# %%
wirecard = yf.Ticker('WDI.DE')

# %%
wirecard.info
# Out:
# {'zip': '85609',
#  'sector': 'Technology',
#  'fullTimeEmployees': 5685,
#  'longBusinessSummary': 'Wirecard AG, a technology company, provides outsourcing and white label solutions for electronic payments worldwide. The company operates in three segments: Payment Processing & Risk Management, Acquiring & Issuing, and Call Center & Communication Services. The Payment Processing & Risk Management segment offers products and service for the acceptance or transactions, and the processing of electronic payments and associated processes. The Acquiring & Issuing segment provides settlement services for credit card sales for online and terminal payments, as well as current accounts with prepaid cards and Girocard/Maestro debit cards; processes payment transactions in various currencies; and issues prepaid and debit cards to private and business customers. The Call Center & Communication Services segment offers value added services, aftersales services to customers, and mailing services. The company also provides payment processing solutions that include Wirecard Payment Page, a payment page; credit card processing; direct debit; online banking payment; alternative payment; international payment processing; tokenization; point of sale terminals; and Wirecard Checkout Portal, a payment portal. In addition, it offers mobile payment solutions; risk management solutions, such as fraud prevention, credit worthiness checks, and individual solutions; integration and testing solutions, including enterprise integration, transaction testing, payment hub, customer self-select PIN, and secure mailer solutions; and communication services. The company serves the consumer goods, digital goods, and travel and mobility sectors. Wirecard has strategic partnerships with Poynt, CreditPilot PLC, SunExpress, and Emonvia. Wirecard AG was founded in 1999 and is headquartered in Aschheim, Germany.',
#  'city': 'Aschheim',
#  'phone': '49 89 4424 1400',
#  'country': 'Germany',
#  'companyOfficers': [],
#  'website': 'http://www.wirecard.com',
#  'maxAge': 1,
#  'address1': 'Einsteinring 35',
#  'fax': '49 89 4424 1500',
#  'industry': 'Software—Application',
#  'previousClose': 104.5,
#  'regularMarketOpen': 100.45,
#  'twoHundredDayAverage': 122.77161,
#  'trailingAnnualDividendYield': 0.0019138756,
#  'payoutRatio': 0.0513,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 102.95,
#  'navPrice': None,
#  'averageDailyVolume10Day': 2918687,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 104.5,
#  'fiftyDayAverage': 116.96083,
#  'trailingAnnualDividendRate': 0.2,
#  'open': 100.45,
#  'toCurrency': None,
#  'averageVolume10days': 2918687,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 0.2,
#  'exDividendDate': 1560902400,
#  'beta': 0.56541,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 97.02,
#  'priceHint': 2,
#  'currency': 'EUR',
#  'trailingPE': 26.045675,
#  'regularMarketVolume': 2057644,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 12541948928,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 2048467,
#  'priceToSalesTrailing12Months': 4.854071,
#  'dayLow': 97.02,
#  'ask': 102.65,
#  'ytdReturn': None,
#  'askSize': None,
#  'volume': 2057644,
#  'fiftyTwoWeekHigh': 162.3,
#  'forwardPE': None,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 0.23,
#  'fiftyTwoWeekLow': 79.68,
#  'bid': 102.65,
#  'tradeable': False,
#  'dividendYield': 0.0019,
#  'bidSize': None,
#  'dayHigh': 102.95,
#  'exchange': 'GER',
#  'shortName': 'WIRECARD AG',
#  'longName': 'Wirecard AG',
#  'exchangeTimezoneName': 'Europe/Berlin',
#  'exchangeTimezoneShortName': 'CET',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '3600000',
#  'quoteType': 'EQUITY',
#  'symbol': 'WDI.DE',
#  'messageBoardId': 'finmb_741774',
#  'market': 'de_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 4.229,
#  'beta3Year': None,
#  'profitMargins': 0.18642999,
#  'enterpriseToEbitda': 14.727,
#  '52WeekChange': -0.14624184,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 123566000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 18.733,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1546214400,
#  'heldPercentInstitutions': None,
#  'netIncomeToCommon': 481700000,
#  'trailingEps': 3.897,
#  'lastDividendValue': None,
#  'SandP52WeekChange': -0.12071997,
#  'priceToBook': 5.418246,
#  'heldPercentInsiders': None,
#  'nextFiscalYearEnd': 1609372800,
#  'mostRecentQuarter': 1569801600,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 114854212,
#  'enterpriseValue': 10927803392,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.572,
#  'dateShortInterest': None,
#  'pegRatio': None,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 100.45,
#  'logo_url': 'https://logo.clearbit.com/wirecard.com'}
